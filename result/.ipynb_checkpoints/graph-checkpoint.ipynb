# %%
import csv
import pandas as pd 
import numpy as np

# %%
genetic_result = pd.read_csv("data/ga_best_stats.csv") 
differential_result = pd.read_csv("data/de_best_stats.csv")

# %%
schwefel_ga = pd.read_csv("data/schwefel/genetic_algorithm/schwefel_fHistory.csv", header=None) 
schwefel_ga_plot = schwefel_ga.plot(kind='box',xticks=np.arange(0, 100+1, 10),
                                    figsize=(8,5),fontsize=15)
schwefel_ga_plot.set_xlabel("10th generation",fontsize=15)
schwefel_ga_plot.set_ylabel("f(x) value",fontsize=15)
fig = schwefel_plot_ga.get_figure()
schwefel_plot_ga.savefig("schwefel_ga_plot.png")
# Out:
# Text(0, 0.5, 'f(x) value')
