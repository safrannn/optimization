# %%
import platform
import psutil

import platform

print('uname    :', platform.uname())
print('system   :', platform.system())
print('node     :', platform.node())
print('release  :', platform.release())
print('version  :', platform.version())
print('machine  :', platform.machine())
print('processor:', platform.processor())
# Out:
# ('uname    :', ('Darwin', 'wlan802-2695.resnet.cwu.edu', '19.3.0', 'Darwin Kernel Version 19.3.0: Thu Jan  9 20:58:23 PST 2020; root:xnu-6153.81.5~1/RELEASE_X86_64', 'x86_64', 'i386'))
# ('system   :', 'Darwin')
# ('node     :', 'wlan802-2695.resnet.cwu.edu')
# ('release  :', '19.3.0')
# ('version  :', 'Darwin Kernel Version 19.3.0: Thu Jan  9 20:58:23 PST 2020; root:xnu-6153.81.5~1/RELEASE_X86_64')
# ('machine  :', 'x86_64')
# ('processor:', 'i386')

# %%
import csv
import pandas as pd

# %%
genetic_result = pd.read_csv("data/ga_best_stats.csv") 
genetic_result

# %%
differential_result = pd.read_csv("data/de_best_stats.csv") 
differential_result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-fefa6a0d8501> in <module>
# ----> 1 differential_result = pd.read_csv("result/de_best_stats.csv")
#       2 differential_result
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
ge_ackleysOne = pd.read_csv("result/ackleysOne_fHistory.csv",delim_whitespace=True) 
ge_ackleysOne.T.plot.line(legend=None)
