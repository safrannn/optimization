# %%
import platform
import psutil

import platform

print('uname    :', platform.uname())
print('system   :', platform.system())
print('node     :', platform.node())
print('release  :', platform.release())
print('version  :', platform.version())
print('machine  :', platform.machine())
print('processor:', platform.processor())
# Out:
# ('Version      :', '2.7.16')
# ('Version tuple:', ('2', '7', '16'))
# ('Compiler     :', 'GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)')
# ('Build        :', ('default', 'Sep 24 2019 16:55:38'))

# %%
import csv
import pandas as pd

# %%
genetic_result = pd.read_csv("ga_best_stats.csv") 
genetic_result
# Out:
#     Function          Mean        Median  Standard Deviation  \
# 0          1  2.483770e+03  2.208040e+03        1.293320e+03
# 1          2  2.893470e+08  2.261830e+08        1.951430e+08
# 2          3  3.492870e+04  2.387940e+04        3.604590e+04
# 3          4  1.475730e+01  1.311400e+01        6.633240e+00
# 4          5  3.584260e-04  2.498780e-04        3.909000e-04
# 5          6  1.014630e+01  1.014630e+01        1.907350e-06
# 6          7  1.591530e+00  6.910680e-03        4.741780e+00
# 7          8  1.596090e+02  1.634570e+02        2.075310e+01
# 8          9  9.630810e-02  5.088040e-02        9.657890e-02
# 9         10  4.997820e-02  3.450390e-02        5.107800e-02
# 10        11  8.141030e-06  6.937580e-07        1.727700e-05
# 11        12  1.212850e-08  6.229250e-11        7.094170e-08
# 12        13  5.408520e-31  3.391140e-43        0.000000e+00
# 13        14  7.008240e+07  3.869070e+07        1.103260e+08
# 14        15  7.383550e+00  7.100130e+00        3.103740e+00
# 15        16  2.659710e+03  2.503320e+03        1.204760e+03
# 16        17  3.214520e+01  3.253180e+01        6.382390e+00
# 17        18  1.694770e+01  1.893990e+01        1.696790e+01
#
#                       Range       Time
# 0           815.169-2516.81    219.6ms
# 1   3.44145e+07-1.70324e+08    151.7ms
# 2           2.45506-14.0631   154.74ms
# 3           5.66619-10.0493   151.68ms
# 4   5.00679e-06-0.000222094    144.1ms
# 5           10.1463-10.1463    191.4ms
# 6    0.000152111-0.00603485    185.8ms
# 7           109.597-185.946    208.4ms
# 8       0.00126648-0.284424   171.26ms
# 9      0.000473022-0.027771    178.1ms
# 10  2.34085e-08-1.92479e-07   156.34ms
# 11  1.16944e-15-6.08028e-11   200.86ms
# 12                      0-0   171.36ms
# 13  5.12044e+06-6.22589e+07   148.46ms
# 14          2.81293-8.24297    215.2ms
# 15          1178.16-2484.42   129.16ms
# 16          22.3023-34.8333   136.24ms
# 17          13.2946-25.9275  6.46822ms
